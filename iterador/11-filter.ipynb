# %% [markdown]
# Filter
# - É usada para filtrar elementos de um iterável com base em uma função que pode retornar True ou False
# - O objetivo é permitir apenas os elementos que satisfazem uma condição.

# %%
#Filtrar números pares (resto da divisão por 2 = 0)
def e_par(x):
    return x % 2 == 0

# %%
numeros = [1, 2, 3, 4, 5, 6]

# %%
numeros_pares = filter(e_par, numeros)
list(numeros_pares)
# Out:
# [2, 4, 6]

# %%
produtos = [
    {"nome":"Produto A", "preco": 10.0, "em_estoque": True},
    {"nome":"Produto B", "preco": 20.0, "em_estoque": False},
    {"nome":"Produto C", "preco": 30.0, "em_estoque": True},
    {"nome":"Produto D", "preco": 40.0, "em_estoque": False}
]

# %%
def produto_em_estoque(produto):
    return produto["em_estoque"]

# %%
produtos_disponiveis = filter(produto_em_estoque, produtos)
list(produtos_disponiveis)
# Out:
# [{'nome': 'Produto A', 'preco': 10.0, 'em_estoque': True},
#  {'nome': 'Produto C', 'preco': 30.0, 'em_estoque': True}]

# %%
transacoes = [200.0, -50.0, 75.0, -30.0, 100.0, -10.0]

# %%
def e_despesa(transacao):
    return transacao < 0

def e_receita(transacao):
    return transacao > 0

# %%
despesas =  filter(e_despesa, transacoes)
print(f"as despesas foram {list(despesas)}")

receitas = filter(e_receita, transacoes)
print(f"as receitas foram {list(receitas)}")

print(f"O saldo final é igual a {sum(transacoes)}")
# Out:
# as despesas foram [-50.0, -30.0, -10.0]
# as receitas foram [200.0, 75.0, 100.0]
# O saldo final é igual a 285.0
